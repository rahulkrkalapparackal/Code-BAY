# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulkrkalapparackal/Code-BAY/blob/main/SEM_II_PythonLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
x = "Everything Everywhere All At Once"
year = 2022
description = "Sci Fi Fantacy Movie"

print(f"My fav movie is {x}")
print(f"The movie was released in {year}")
print(f"My fav movie {x} was released in {year}")
print(f"My fav movie {x} released in {year} is a {description}")
# Out:
# My fav movie is Everything Everywhere All At Once
# The movie was released in 2022
# My fav movie Everything Everywhere All At Once was released in 2022
# My fav movie Everything Everywhere All At Once released in 2022 is a Sci Fi Fantacy Movie

# %%
# subject
sub = "Econometrics"
description="love the practical side of the subject in the formulation of economical policies"
print (f"I like {sub} because I {description}")
# Out:
# I like Econometrics because I love the practical side of the subject in the formulation of economical policies

# %%
#input function
name = input("what is your name? ")
print(name)
age=input("what is your age? ")
print(age)
# Out:
# what is your name? Rahul
# Rahul
# what is your age? 23
# 23

# %%
x=10
y=30
z=x+y
print (z)
print (type(z))
# Out:
# 40
# <class 'int'>

# %%
print ((2*3)+7*7)
# Out:
# 55

# %%
age=int(input ("what is your age? "))
print(age)
# Out:
# what is your age? 23
# 23

# %%
name=input("what's your name?")
age=input("what's your age?")
color=input ("what's your fav color? ")
food=input("what's your fav food! ")
hobby=input ("what's your hobby?")
passion=input("what's your passion? ")
print(f"I am {name}, {age} years old. My fav color in {color} and fav food is {food}. I spent my free time for {hobby} and am passionate about learning {passion}")
# Out:
# what's your name?Rahul
# what's your age?23
# what's your fav color? Red
# what's your fav food! Tandoori Chicken
# what's your hobby?Swimming
# what's your passion? Finances
# I am Rahul, 23 years old. My fav color in Red and fav food is Tandoori Chicken. I spent my free time for Swimming and am passionate about learning Finances

# %%
my_dict = {"name": "Rahul","age": 22,"course": "Finance"}
print(my_dict["name"])
print(my_dict["name"])
my_dict["age"] = 23
my_dict["city"] = "Kochi"


category = {"birds": ["Eagle", "Parrot", "Sparrow", "Peacock", "Owl"],"mammals": ["Lion", "Elephant", "Tiger", "Dog", "Whale"],
    "foods": ["Pizza", "Burger", "Biryani", "Pasta", "Salad"]
}
category["foods"]
# Out:
# Rahul
# Rahul
# ['Pizza', 'Burger', 'Biryani', 'Pasta', 'Salad']

# %%
def introduce(name, age):
    return f"My name is {name} and I am {age} years old."

print(introduce("Rahul", 22))

# %%
def cbs(**keyword):
    print(keyword)

cbs(name="Rahul K R", age=23, course="MSc Econometrics & Fintech")
# Out:
# {'name': 'Rahul K R', 'age': 23, 'course': 'MSc Econometrics & Fintech'}
